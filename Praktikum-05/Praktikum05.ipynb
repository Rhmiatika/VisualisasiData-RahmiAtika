# %% [markdown]
# Praktikum 5: Matplotlib - Scatter PlotKelompok 28 - Visualisasi Data
#
# 1. Rahmi Atiika - 0110222279
# 2. Saskia Putri Ananda - 0110222159
# 3. Noer Muhammad Ayub - 0110222142

# %% [markdown]
# SCATTER PLOT DENGAN MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# Data Dummy

suhu = [20, 22, 24, 26, 28, 30, 32, 34, 36]
penjualan = [50, 60, 70, 90, 100, 110, 130, 150, 180]

# Membuat scatter plot
plt.scatter(suhu, penjualan, color='blue')
plt.title('Hubungan Penjualan Es Krim dan SUhu')
plt.xlabel('Suhu (`C)')
plt.ylabel('Penjualan Es Krim')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# KUSTOMISASI SCATTER PLOT

# %%
import matplotlib.pyplot as plt

# Data Dummy

suhu = [20, 22, 24, 26, 28, 30, 32, 34, 36]
penjualan = [50, 60, 70, 90, 100, 110, 130, 150, 180]

# Kustomisasi scatter plot
plt.scatter(suhu, penjualan, color='orange', s=100, edgecolor='black', alpha=0.7)
plt.title('Hubungan Penjualan Es Krim dan SUhu')
plt.xlabel('Suhu (°C)')
plt.ylabel('Penjualan Es Krim')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# MENAMBAHKAN SCATTER PLOT

# %%
import matplotlib.pyplot as plt

# Data dummy
suhu = [20, 22, 24, 26, 28, 30, 32, 34, 36]

# Data tambahan untuk kategori hari
penjualan_kerja = [50, 60, 70, 80, 90, 100, 110, 120, 130]
penjualan_akhir_pekan = [60, 70, 80, 100, 110, 120, 140, 160, 200]

# Scatter plot multiple
plt.scatter(suhu, penjualan_kerja, color='green', label='Hari Kerja', s=80)
plt.scatter(suhu, penjualan_akhir_pekan, color='purple', label='Akhir Pekan', s=80)

plt.title('Penjualan Es Krim Berdasarkan Hari')
plt.xlabel('Suhu (°C)')
plt.ylabel('Penjualan Es Krim')
plt.legend()
plt.show()

# %% [markdown]
# SCATTER PLOT UNTUK MELIHAT HUBUNGAN DATA DENGAN BEBERAPA VARIABEL

# %%
import matplotlib.pyplot as plt

# Data dummy
suhu = [20, 22, 24, 26, 28, 30, 32, 34, 36]
penjualan = [50, 60, 70, 90, 100, 110, 130, 150, 180]

# Data tambahan
kelembapan = [60, 65, 70, 75, 80, 85, 90, 95, 100]
ukuran_titik = [200, 220, 240, 260, 280, 300, 320, 340, 360]

# Scatter plot dengan ukuran dan warna yang bervariasi
plt.scatter(suhu, penjualan, c=kelembapan, s=ukuran_titik, cmap='coolwarm', alpha=0.6)

plt.title('Hubungan Penjualan, Suhu, dan Kelembapan')
plt.xlabel('Suhu (°C)')
plt.ylabel('Penjualan Es Krim')
plt.colorbar(label='Kelembapan (%)')

plt.show()

# %% [markdown]
# 3D SSCATTER PLOT

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# dataset suhu
suhu = [22, 22, 24, 26, 28, 30, 32, 34, 36]

# dataset penjualan
penjualan_weekday = [50, 60, 70, 80, 90, 100, 110, 120, 130]
penjualan_weekend = [60, 70, 80, 100, 110, 120, 140, 160, 200]

# 3D Scatter Plot
fig = plt.figure(figsize=(15, 13))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(suhu, penjualan_weekday, penjualan_weekend,
           color='orange', s=100, label='Data Penjualan')

ax.set_title("Hubungan Penjualan Es Krim dan Suhu (3D ver.)")
ax.set_xlabel("Suhu (°C)")
ax.set_ylabel("Penjualan Weekdays")
ax.set_zlabel("Penjualan Weekend")

plt.show()
